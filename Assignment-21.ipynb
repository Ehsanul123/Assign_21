# %%
#(1)-Add the current date to the text file today.txt as a string.

import datetime
# Code to Add current date to the today.txt file
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
# Code to Read current date from today.txt file
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 02-01-2023

# %%
#(2)- Read the text file today.txt into the string today_string

file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 02-01-2023

# %%
#(3)- Parse the date from today_string.

from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2023-01-02 00:00:00

# %%
#(4)- List the files in your current directory

import os
for root, dirs, files in os.walk('.', topdown=True):
    dirs.clear() 
    for file in files:
      print(file)
# Out:
# .gitconfig
# a.json
# a.pdf
# AgentLogingReport.csv
# AgentPerformance.csv
# All Task Solution.ipynb
# Assignment-10.ipynb
# Assignment-11.ipynb
# Assignment-12.ipynb
# Assignment-13.ipynb
# Assignment-14.ipynb
# Assignment-15.ipynb
# Assignment-16.ipynb
# Assignment-17.ipynb
# Assignment-18.ipynb
# Assignment-20.ipynb
# Assignment-21.ipynb
# Assignment-3.ipynb
# Assignment-5.ipynb
# Assignment-6.ipynb
# Assignment-7.ipynb
# Assignment-8.ipynb
# Assignment-9.ipynb
# Assignment1.py.ipynb
# Assignment_2.ipynb
# Assignment_4.ipynb
# Attribute DataSet.xlsx
# b.pdf
# ban.csv
# bank.csv
# books.csv
# books.db
# class Assignment.ipynb
# Demo1.ipynb
# Dress Sales.xlsx
# EDA1.ipynb
# Exception Handling rev.ipynb
# Final Sheet (Ship Date -Sep and Oct)-SMU - Copy.xlsx
# first.ipynb
# For Loop.ipynb
# From While_loop.ipynb
# Function.ipynb
# Function1.ipynb
# Graph_lec.ipynb
# haberman.csv
# haberman.names
# hel.mp3
# hell.mp3
# hello.mp3
# If elif If Condition.ipynb
# ineu.jpg
# Inventory analysis_ Q3-2022 fashion and Q3-2022 energy_220712.xlsx
# Iterrator, Generator,Map,Reduce,Filter,Basic file operation.ipynb
# List,Tuple, Dictionary.ipynb
# NTUSER.DAT
# ntuser.dat.LOG1
# ntuser.dat.LOG2
# NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf
# NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms
# NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms
# ntuser.ini
# num_py.ipynb
# Online Retail (1).xlsx
# Online Retail.xlsx
# online_retail_II (1).xlsx
# paandaas3.ipynb
# pandaas1.ipynb
# pandaas2.ipynb
# pandas basic.ipynb
# pandas2.ipynb
# Pandas3.ipynb
# panprac.py.ipynb
# Pasdas1.ipynb
# PM_Q3-EN_Inven_Analysis_072722.xlsx
# pollution.csv
# pollution.names
# Practice.ipynb
# Prog_Assign_1.ipynb
# Prog_Assign_2.ipynb
# Prog_Assign_3.ipynb
# Prog_Assign_4.ipynb
# Prog_Assign_5.ipynb
# sales_data_final.csv
# scr.txt
# ScrabProject.ipynb
# sd.txt
# ste.txt
# sudh.txt
# test.json
# test.st
# test.sudh
# test.txt
# test1.txt
# test12.json
# test2.txt
# test3.sudh
# test4.txt
# test5.txt
# test6.txt
# test6.txt.txt
# text.txt
# today.txt
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# Untitled6.ipynb
# Untitled7.ipynb
# Untitled8.ipynb
# URL Table.txt
# Variable_revision1.ipynb
# While Loop.ipynb
# zoo.ipynb
# zoo.py

# %%
#(5)-Create a list of all of the files in your parent directory (minimum five files should be available).

import os 
os.listdir()
# Out:
# ['.astropy',
#  '.azuredatastudio',
#  '.conda',
#  '.cufflinks',
#  '.git',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.VirtualBox',
#  '3D Objects',
#  'a.json',
#  'a.pdf',
#  'AgentLogingReport.csv',
#  'AgentPerformance.csv',
#  'All Task Solution.ipynb',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Assignment-10.ipynb',
#  'Assignment-11.ipynb',
#  'Assignment-12.ipynb',
#  'Assignment-13.ipynb',
#  'Assignment-14.ipynb',
#  'Assignment-15.ipynb',
#  'Assignment-16.ipynb',
#  'Assignment-17.ipynb',
#  'Assignment-18.ipynb',
#  'Assignment-20.ipynb',
#  'Assignment-21.ipynb',
#  'Assignment-3.ipynb',
#  'Assignment-5.ipynb',
#  'Assignment-6.ipynb',
#  'Assignment-7.ipynb',
#  'Assignment-8.ipynb',
#  'Assignment-9.ipynb',
#  'Assignment1.py.ipynb',
#  'Assignment_2.ipynb',
#  'Assignment_4.ipynb',
#  'Attribute DataSet.xlsx',
#  'b.pdf',
#  'ban.csv',
#  'bank.csv',
#  'books.csv',
#  'books.db',
#  'class Assignment.ipynb',
#  'Contacts',
#  'Cookies',
#  'Demo1.ipynb',
#  'Documents',
#  'Downloads',
#  'Dress Sales.xlsx',
#  'EDA1.ipynb',
#  'Exception Handling rev.ipynb',
#  'Favorites',
#  'Final Sheet (Ship Date -Sep and Oct)-SMU - Copy.xlsx',
#  'first.ipynb',
#  'For Loop.ipynb',
#  'From While_loop.ipynb',
#  'Function.ipynb',
#  'Function1.ipynb',
#  'Graph_lec.ipynb',
#  'haberman.csv',
#  'haberman.names',
#  'hel.mp3',
#  'hell.mp3',
#  'hello.mp3',
#  'If elif If Condition.ipynb',
#  'ineu.jpg',
#  'IntelGraphicsProfiles',
#  'Inventory analysis_ Q3-2022 fashion and Q3-2022 energy_220712.xlsx',
#  'Iterrator, Generator,Map,Reduce,Filter,Basic file operation.ipynb',
#  'Links',
#  'List,Tuple, Dictionary.ipynb',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'num_py.ipynb',
#  'OneDrive',
#  'Online Retail (1).xlsx',
#  'Online Retail.xlsx',
#  'online_retail_II (1).xlsx',
#  'Oracle',
#  'paandaas3.ipynb',
#  'pandaas1.ipynb',
#  'pandaas2.ipynb',
#  'pandas basic.ipynb',
#  'pandas2.ipynb',
#  'Pandas3.ipynb',
#  'panprac.py.ipynb',
#  'Pasdas1.ipynb',
#  'PM_Q3-EN_Inven_Analysis_072722.xlsx',
#  'pollution.csv',
#  'pollution.names',
#  'Postman',
#  'Practice.ipynb',
#  'PrintHood',
#  'Prog_Assign_1.ipynb',
#  'Prog_Assign_2.ipynb',
#  'Prog_Assign_3.ipynb',
#  'Prog_Assign_4.ipynb',
#  'Prog_Assign_5.ipynb',
#  'PycharmProjects',
#  'Recent',
#  'sales_data_final.csv',
#  'Saved Games',
#  'scr.txt',
#  'ScrabProject.ipynb',
#  'sd.txt',
#  'seaborn-data',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'ste.txt',
#  'sudh.txt',
#  'Templates',
#  'test.json',
#  'test.st',
#  'test.sudh',
#  'test.txt',
#  'test1.txt',
#  'test12.json',
#  'test2.txt',
#  'test3.sudh',
#  'test4.txt',
#  'test5.txt',
#  'test6.txt',
#  'test6.txt.txt',
#  'text.txt',
#  'today.txt',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'URL Table.txt',
#  'Variable_revision1.ipynb',
#  'Videos',
#  'While Loop.ipynb',
#  'zoo.ipynb',
#  'zoo.py',
#  '__pycache__']

# %%
'''(6)-Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.
'''
import multiprocessing
import time 
import random
import datetime

def procOne():
    print(f'Proc_one_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_one_Endtime -> {datetime.datetime.now()}')
    
def procTwo():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')

def procThree():
    print(f'Proc_two_Starttime -> {datetime.datetime.now()}')
    time.sleep(random.randint(1,5))
    print(f'Proc_two_Endtime -> {datetime.datetime.now()}')
    
if __name__ == "__main__":    
    p1 = multiprocessing.Process(target=procOne)
    p2 = multiprocessing.Process(target=procTwo)
    p3 = multiprocessing.Process(target=procThree)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

# %%
#(7)-Create a date object of your day of birth.

from datetime import datetime
my_dob = datetime.strptime('22/04/1995','%d/%m/%Y')
print(my_dob)
# Out:
# 1995-04-22 00:00:00

# %%
#(8)- What day of the week was your day of birth

from datetime import datetime
my_dob = datetime(1995,4,22)
my_dob.strftime("%A")
# Out:
# 'Saturday'

# %%
#(9)-. When will you be (or when were you) 10,000 days old.

from datetime import datetime, timedelta
my_dob = datetime.strptime("22/04/1995",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1967, 12, 5, 0, 0)
